# %%
import sys 
import os
import numpy as np
import matplotlib.pyplot as plt
from sswm import SM_C_H
from create_figs import *
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Description**
#
# This notebook executes scripts in this repository to visualize results from the analysis of data-driven versus optimality-based ecosystem water use strategies at study sites in:
#
# M Bassiouni, S Manzoni, and G Vico (in prep). Optimal ecosystem water use strategies explain soil moisture variability.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
res_opt = pd.read_csv( '../../DATA/WUS/WUS_output/combined/results_opt__1.csv')
res_dd = pd.read_csv( '../../DATA/WUS/WUS_output/combined/results_bf__1.csv')

# %%
scatter_all_metrics(res_opt, res_dd, 'dynamic_1')
# Out:
# 40 2 1 NSE data-driven: 0.90 ; NSE optimality-based: 0.66
# beta_ww  R2:  0.90 ( 0.00); RMSD:0.10
# s_star  R2:  0.87 ( 0.00); RMSD:0.08
# s_wilt  R2:  0.93 ( 0.00); RMSD:0.05
# pi_F  R2:  0.92 ( 0.00); RMSD:0.29
# pi_R  R2:  0.41 ( 0.01); RMSD:0.37
# AA  R2:  0.88 ( 0.00); RMSD:0.10
# epsilon  R2:  0.91 ( 0.00); RMSD:0.08

# %%
piF_piR_scatter(res_dd, res_opt)
# Out:
# -0.13 (0.03 )
# -0.10 (0.01 )

# %%
tet_part(res_dd)
